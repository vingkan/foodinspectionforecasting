# %%
import pandas as pd
import numpy as np
import scipy.stats as stat
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import math
import textdistance
import string

# %%
from research.strings import VIOLATIONS, MONTHS

# %%
df_canvass = pd.read_csv("data/canvass_records.csv.gz")
df_canvass["critical_found"] = df_canvass[VIOLATIONS].max(axis=1)
print("Read {} canvass records.".format(len(df_canvass)))
# Out:
# Read 50462 canvass records.

# %%
def clean_name(original, backup, fallback="nullname"):
    name = fallback
    if not pd.isna(original):
        name = original
    elif not pd.isna(backup):
        name = backup
    clean = name.casefold()
    for p in list(string.punctuation):
        clean = clean.replace(p, "")
    clean = clean.replace(" ", "_")
    return clean

# %%
name_opts = df_canvass[["aka_name", "dba_name"]].to_dict(orient="records")
df_canvass["clean_name"] = [clean_name(n["aka_name"], n["dba_name"]) for n in name_opts]

# %%
top_names = df_canvass.groupby("clean_name")["inspection_id"].count().sort_values(ascending=False)
all_names = list(top_names.index)
top_names.head(70)
# Out:
# clean_name
# subway                           1822
# dunkin_donuts                     589
# jimmy_johns                       230
# mcdonalds                         204
# chipotle_mexican_grill            192
# starbucks_coffee                  176
# potbelly_sandwich_works           168
# corner_bakery_cafe                141
# au_bon_pain                       141
# subway_sandwiches                 126
# potbelly_sandwich_works_llc       118
# dunkin_donutsbaskin_robbins       116
# starbucks                         113
# dominos_pizza                     102
# freshii                           100
# popeyes                            88
# dunkin_donuts_baskin_robbins       80
# mc_donalds                         76
# burger_king                        73
# taco_bell                          69
# see_thru_chinese_kitchen           69
# protein_bar                        68
# wendys                             67
# dunkin_donuts__baskin_robbins      61
# pizza_hut                          61
# pockets                            60
# pret_a_manger                      59
# panda_express                      59
# kfc                                57
# panera_bread                       57
#                                  ...
# kentucky_fried_chicken             47
# wow_bao                            45
# sarpinos_pizzeria                  44
# tokyo_lunch_boxes__catering        43
# als_beef                           42
# jamba_juice                        42
# popeyes_chicken                    41
# hannahs_bretzel                    40
# cosi                               40
# papa_johns_pizza                   39
# potbelly                           37
# epic_burger                        36
# subway_sandwich                    36
# taco_fresco                        36
# arbys                              34
# caffe_baci                         34
# main_kitchen                       34
# taco__burrito_house                34
# sbarro                             33
# afc_sushi                          33
# mr_submarine                       32
# rosatis_pizza                      31
# potbelly_sandwich_shop             31
# edible_arrangements                31
# little_caesar_pizza                30
# j__j_fish                          30
# chicagos_pizza                     30
# sharks_fish__chicken               29
# mezza                              29
# qdoba_mexican_grill                28
# Name: inspection_id, Length: 70, dtype: int64

# %%
search = "afc_sushi"
for name in all_names:
    sim = textdistance.jaro_winkler(search, name)
    if sim > 0.85:
        print(name)
# Out:
# afc_sushi
# afc_sushijewelosco_3241
# afc_sushi__walgreens
# afc_sushi__dominicks
# kai_sushi
# afc_sushi__jewel_osco
# ra_sushi
# afc_sushi__marshall_fields
# afc_sushi__university_center
# afc_sushidominicks_1113
# afc_sushi__dominicks_1100
# afc_sushi__cafe_300
# afc_sushiuniversity_of_chicago
# afc_sushi__jewel_osco_3224

# %%
textdistance.jaro("potbelly_sandwich_works", "potbelly_sandwich_works_llc")
# Out:
# 0.9506172839506174

# %%
df_canvass.query("clean_name == 'main_kitchen__great'")
# Out:
#        inspection_id         address              aka_name     city  \
# 11014         251222  1 W WACKER DR   MAIN KITCHEN / GREAT  CHICAGO
# 15781        2099137  1 W WACKER DR   MAIN KITCHEN / GREAT  CHICAGO
# 20170        1578216  1 W WACKER DR   MAIN KITCHEN / GREAT  CHICAGO
# 32753        1995219  1 W WACKER DR   MAIN KITCHEN / GREAT  CHICAGO
# 36171        1138777  1 W WACKER DR   MAIN KITCHEN / GREAT  CHICAGO
# 44493        1372362  1 W WACKER DR   MAIN KITCHEN / GREAT  CHICAGO
# 44837        1689252  1 W WACKER DR   MAIN KITCHEN / GREAT  CHICAGO
# 46029         567309  1 W WACKER DR   MAIN KITCHEN / GREAT  CHICAGO
# 49705        2160126  1 W WACKER DR   MAIN KITCHEN / GREAT  CHICAGO
#
#                         dba_name facility_type          inspection_date  \
# 11014  RENAISSANCE CHICAGO HOTEL    Restaurant  2010-06-23T00:00:00.000
# 15781  RENAISSANCE CHICAGO HOTEL    Restaurant  2017-10-19T00:00:00.000
# 20170  RENAISSANCE CHICAGO HOTEL    Restaurant  2015-09-28T00:00:00.000
# 32753  RENAISSANCE CHICAGO HOTEL    Restaurant  2017-03-08T00:00:00.000
# 36171  RENAISSANCE CHICAGO HOTEL    Restaurant  2013-01-22T00:00:00.000
# 44493  RENAISSANCE CHICAGO HOTEL    Restaurant  2014-01-29T00:00:00.000
# 44837  RENAISSANCE CHICAGO HOTEL    Restaurant  2016-03-08T00:00:00.000
# 46029  RENAISSANCE CHICAGO HOTEL    Restaurant  2011-03-25T00:00:00.000
# 49705  RENAISSANCE CHICAGO HOTEL    Restaurant  2018-04-16T00:00:00.000
#
#       inspection_type   latitude  license_id  ...  V7 V8 V9 V10 V11  V12  V13  \
# 11014         Canvass  41.886704       48221  ...   0  0  0   0   0    0    0
# 15781         Canvass  41.886704       48221  ...   0  0  0   0   0    0    0
# 20170         Canvass  41.886704       48221  ...   0  0  0   0   0    0    0
# 32753         Canvass  41.886704       48221  ...   0  0  0   0   0    0    0
# 36171         Canvass  41.886704       48221  ...   0  0  0   0   0    0    0
# 44493         Canvass  41.886704       48221  ...   0  0  0   0   0    0    0
# 44837         Canvass  41.886704       48221  ...   0  0  0   0   0    0    0
# 46029         Canvass  41.886704       48221  ...   0  0  0   0   0    0    0
# 49705         Canvass  41.886704       48221  ...   0  0  0   0   0    0    0
#
#        V14  critical_found           clean_name
# 11014    0               0  main_kitchen__great
# 15781    0               0  main_kitchen__great
# 20170    0               1  main_kitchen__great
# 32753    0               0  main_kitchen__great
# 36171    0               0  main_kitchen__great
# 44493    0               0  main_kitchen__great
# 44837    0               0  main_kitchen__great
# 46029    0               1  main_kitchen__great
# 49705    0               1  main_kitchen__great
#
# [9 rows x 36 columns]
