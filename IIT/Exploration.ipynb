# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SPLIT_DATE = 16252
df = pd.read_csv("data/inspections.csv")
df = df.query("Inspection_Date < {}".format(SPLIT_DATE))
df.head(3)
# Out:
#    pastSerious  pastCritical  timeSinceLast  ageAtInspection  \
# 0          0.0           0.0            2.0                1
# 1          0.0           0.0            2.0                1
# 2          0.0           0.0            2.0                1
#
#    consumption_on_premises_incidental_activity  tobacco_retail_over_counter  \
# 0                                          0.0                          1.0
# 1                                          0.0                          0.0
# 2                                          0.0                          0.0
#
#    temperatureMax  heat_burglary  heat_sanitation  heat_garbage   ...     \
# 0       53.496667      26.992376        37.748787     12.768572   ...
# 1       59.046667      13.976557        15.412267     12.895485   ...
# 2       59.046667      12.611239         8.320330      8.004220   ...
#
#            inspection_date  inspection_type   latitude  license_id  longitude  \
# 0  2013-01-31T00:00:00.000          Canvass  41.943359     30790.0 -87.644999
# 1  2011-10-18T00:00:00.000          Canvass  41.991919   1475890.0 -87.709631
# 2  2011-10-18T00:00:00.000          Canvass  41.995632   1740130.0 -87.712707
#
#    results           risk  state  \
# 0     Pass   Risk 3 (Low)     IL
# 1     Pass  Risk 1 (High)     IL
# 2     Fail  Risk 1 (High)     IL
#
#                                           violations      zip
# 0  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60657.0
# 1  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  60659.0
# 2  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  60659.0
#
# [3 rows x 35 columns]
